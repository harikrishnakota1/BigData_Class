# %%
For this challenge, the hint is to use the urllib and asked us to not to try all nothings. 
To try the nothing we have a link in the page source "linkedlist.php?nothing=12345". 
When I clicked this link, this gave a another number and so on. 
So, I first thought of reading all the numbers. Where I found two empty spaces at 16044 & 66831.
When tried with 16044. There is a hint to move on. 
When tried with 66831. I got peak.html.

# %%
import urllib
nothing="12345"
for i in range(400):
    url="http://www.pythonchallenge.com/pc/def/linkedlist.php?nothing=" +nothing
    f = urllib.urlopen(url)
    file = f.read()
    nothing = str(filter(str.isdigit,file))
    print nothing
# Out:
# 44827
# 45439
# 94485
# 72198
# 80992
# 8880
# 40961
# 58765
# 46561
# 13418
# 41954
# 46782
# 92730
# 89229
# 25646
# 74288
# 25945
# 39876
# 8498
# 34684
# 62316
# 71331
# 59717
# 76893
# 44091
# 73241
# 19242
# 17476
# 39566
# 81293
# 25857
# 74343
# 39410
# 5505
# 27104
# 54003
# 23501
# 21110
# 88399
# 49740
# 31552
# 39998
# 19755
# 64624
# 37817
# 43427
# 15115
# 44327
# 7715
# 15248
# 61895
# 54759
# 54270
# 51332
# 63481
# 12362
# 94476
# 87810
# 6027
# 47551
# 79498
# 81226
# 4256
# 62734
# 25666
# 14781
# 21412
# 55205
# 65516
# 53535
# 4437
# 43442
# 91308
# 1312
# 36268
# 34289
# 46384
# 18097
# 9401
# 54249
# 29247
# 13115
# 23053
# 3875
# 16044
#
# 72758
# 71301
# 55577
# 88786
# 32293
# 87798
# 24838
# 66137
# 88016
# 36876
# 33179
# 90231
# 17825
# 84361
# 99222
# 87348
# 47100
# 90650
# 84369
# 36116
# 96544
# 62892
# 43790
# 67652
# 32839
# 5353
# 63153
# 48029
# 84141
# 14662
# 78566
# 18131
# 710
# 67500
# 34992
# 64568
# 8155
# 30579
# 11629
# 32490
# 47936
# ...

# %%
Just to checked the particular url

# %%
import urllib
url1="http://www.pythonchallenge.com/pc/def/linkedlist.php?nothing=66831" 
a = urllib.urlopen(url1)
print "".join(a)
# Out:
# peak.html
